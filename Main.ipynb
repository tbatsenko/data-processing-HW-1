# %% [markdown]
# # Analysing gender in ecology publications

# %% [markdown]
# ### Loading the data

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import csv
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# Let us load the data as a pandas dataframe.

# %%
data = pd.read_csv("new_journals_data.csv", sep = ",")
len(data)
# Out:
# 2532

# %% [markdown]
# ### Exploring the data
# Now take a look at the dataset and its features:

# %%
data.head(5)
# Out:
#    Unnamed: 0                                                 TI  \
# 0           1  Ecology Letters, and Transparency and Openness...
# 1           2  The relative importance of trait vs. genetic d...
# 2           3  Test of biotic and abiotic correlates of latit...
# 3           4  Multi-trophic consequences of plant genetic va...
# 4           5  Parameterisation and validation of a resource ...
#
#                    SO LeadAuthorFirst LeadAuthorLast LeadInitOnly  \
# 0     ECOLOGY LETTERS             NaN        daniels           no
# 1             ECOLOGY         Jessica        hoareau           no
# 2  JOURNAL OF ECOLOGY            Luis         morard           no
# 3             ECOLOGY            Luis           soul           no
# 4     ECOLOGY LETTERS        Tomoyuki        farrell           no
#
#   first.gender.manual first.gender first.gender.manual.method EditorFirst  \
# 0                 NaN          NaN                        NaN         NaN
# 1              female       female                        NaN    Jonathan
# 2                male         male                        NaN    Jennifer
# 3                male         male                        NaN       James
# 4                 NaN          NaN                        NaN        Liza
#
#   EditorLast editor.gender.manual                       FirstInst2  \
# 0        NaN                  NaN                              NaN
# 1  Grabowski                 male   University of California Davis
# 2        Lau               female  Universidad Autonoma de Yucatan
# 3     Cronin                 male  Universidad Autonoma de Yucatan
# 4     Comita               female                              NaN
#
#            Editor.Institution
# 0                         NaN
# 1     Northeastern University
# 2   Michigan State University
# 3  Louisiana State University
# 4             Yale University

# %%
data.dtypes
# Out:
# Unnamed: 0                     int64
# TI                            object
# SO                            object
# LeadAuthorFirst               object
# LeadAuthorLast                object
# LeadInitOnly                  object
# first.gender.manual           object
# first.gender                  object
# first.gender.manual.method    object
# EditorFirst                   object
# EditorLast                    object
# editor.gender.manual          object
# FirstInst2                    object
# Editor.Institution            object
# dtype: object

# %% [markdown]
# ### Clear the data from fields we don't need
# Delete all data about gender

# %%
data = data.drop(columns=["LeadInitOnly",
                             "first.gender.manual",
                             "first.gender",
                             "first.gender.manual.method",
                             "editor.gender.manual",
                            ])

# %% [markdown]
# ### Fix columns naming
# For the simplicity let's fix the naming to a more logical one

# %%
data.rename(columns={'Unnamed': 'index',
                     'TI':'title',
                     'SO':'type',
                     'LeadAuthorFirst':'author_first_name',
                     'LeadAuthorLast':'author_last_name',
                     'EditorFirst':'editor_first_name',
                     'EditorLast':'editor_last_name',
                     'FirstInst2':'author_institution',
                     'Editor.Institution':'editor_institution',
                    }, 
                 inplace=True)

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# title                 object
# type                  object
# author_first_name     object
# author_last_name      object
# editor_first_name     object
# editor_last_name      object
# author_institution    object
# editor_institution    object
# dtype: object

# %% [markdown]
# Take only those records where author_first_name & editor_first_name are valid

# %%
len(data)
# Out:
# 2532

# %%
data = data[data['author_first_name'].notnull()]
# data = data[not(len(data['author_first_name']) == 2 and data['author_first_name'][1] == ".")]
data = data[data['editor_first_name'].notnull()]
# data = data[len(data['editor_first_name']) > 2 and data['editor_first_name'][1] != "."]

# %%
len(data)
# Out:
# 2425

# %% [markdown]
# ### TODO: label women or men using genderize.io API and (cp + 4 / p + 2) normalization

# %%
hashmap = {}
rows_to_del = []

indx = 0

for index, row in data.iterrows():
    if len(row['author_first_name']) == 2 and row['author_first_name'][1] == ".":
        rows_to_del.append(indx)
    elif row['author_first_name'] in hashmap:
        hashmap[row['author_first_name']] += 1
    else:
        hashmap[row['author_first_name']] = 1
    indx += 1

for index, row in data.iterrows():
    if len(row['editor_first_name']) == 2 and row['editor_first_name'][1] == ".":
        rows_to_del.append(indx)
    elif row['editor_first_name'] in hashmap:
        hashmap[row['editor_first_name']] += 1
    else:
        hashmap[row['editor_first_name']] = 1
    indx += 1

for idx in rows_to_del: 
    data.drop(data.index[[idx]])
print(hashmap.keys())
# Out:
# dict_keys(['Jessica', 'Luis', 'Tomoyuki', 'Andre', 'Peter', 'Dean', 'Vanessa', 'Michelle', 'Anurag', 'Ken', 'Dirk', 'Masahiro', 'Christina', 'Marcelo', 'Susanne', 'Patrick', 'Diogo', 'Arnaud', 'Christoffer', 'Joerg', 'Helen', 'Adam', 'Hamid', 'Eric', 'Daniel', 'Maximilian', 'Jacob', 'Andrew', 'David', 'Maria', 'Florian', 'Karie', 'Diego', 'Isabel', 'Priyanga', 'Roberto', 'Tomotsune', 'Aitor', 'Francis', 'Sarah', 'Mette', 'Marti', 'Matthew', 'Thomas', 'Weston', 'Sonia', 'Dvir', 'Patricia', 'Yimen', 'Gerardo', 'Miguel', 'Alicia', 'Hector', 'Jonathan', 'Xavier', 'Jennifer', 'Paula', 'Samuel', 'Sonya', 'Marie', 'Gabriel', 'Willem', 'Amy', 'Colin', 'Tal', 'Jose', 'Ranen', 'Eliran', 'Sandro', 'Benura', 'Benedicte', 'Ruxandra', 'Guy', 'Sara', 'Lander', 'Robert', 'Wenming', 'Ida', 'Liam', 'Diane', 'Andy', 'EmilyClare', 'Timothy', 'Jesus', 'Aabir', 'Natalie', 'Gyoergy', 'Marion', 'Shannon', 'Nicholas', 'Albert', 'Allison', 'Lewis', 'Felipe', 'Luke', 'Ceres', 'Frederic', 'Louise', 'Andres', 'Mathieu', 'Ronald', 'Marinelle', 'Jens', 'Guillaume', 'Kaitlin', 'Virgile', 'Mark', 'Jeremy', 'Michael', 'Niko', 'Abdelkader', 'Kevin', 'Boris', 'James', 'Edwige', 'Maira', 'Joscha', 'Cassandra', 'Alison', 'Joseph', 'Scott', 'Miles', 'Ali', 'Reut', 'Maud', 'Massimo', 'Shimon', 'Yann', 'Elvire', 'Ricardo', 'Gustavo', 'Hawthorne', 'Tracey', 'Simeon', 'Radika', 'Shipra', 'Maloyjo', 'Jiang-Hui', 'Clotilde', 'Filip', 'Dimitri', 'Jay', 'Ewan', 'Tom', 'Uddipta', 'Eirin', 'Tim', 'Paul', 'Benjamin', 'Manuel', 'Elizabeth', 'Gionata', 'Steffen', 'Kate', 'Maarten', 'Carl', 'Monika', 'Folmer', 'Katharina', 'Russell', 'Maxime', 'Richard', 'Bridget', 'Michal', 'Zoltan', 'Filippo', 'Veronique', 'Stephanie', 'Sandra', 'Charlotte', 'Selina', 'Bethany', 'Mariana', 'Vincent', 'Angela', 'Kari', 'Frank', 'Travis', 'Stefan', 'Mario', 'Jedediah', 'Chris', 'Jeffrey', 'Lindell', 'Kristin', 'Emma', 'Mollie', 'Brian', 'Bryan', 'Calum', 'Carissa', 'Christopher', 'Gregory', 'Leone', 'Annalis', 'Nicolas', 'Lars', 'Yannick', 'John', 'Hannah', 'Yvonne', 'Frances', 'Arne', 'Phillip', 'Rebecca', 'Ulf', 'Karin', 'Romina', 'Hugh', 'Edward', 'Falko', 'Raymond', 'Fernando', 'Alexander', 'Francesca', 'Justin', 'Kim', 'Erin', 'Meghan', 'Brandon', 'Ulrika', 'Stefano', 'Minh', 'Pol', 'Isabella', 'Marta', 'Marcel', 'Andrea', 'Pedro', 'Tomas', 'Gunnar', 'Stephen', 'Francesco', 'Paola', 'Raul', 'Martha', 'Max', 'Adrian', 'Santiago', 'Laura', 'Bruno', 'Jane', 'Lorenzo', 'Renee', 'Hugo', 'Giovanni', 'Ann', 'Yosra', 'Stotra', 'Mahul', 'Loic', 'Juliette', 'Thierry', 'Chia-Hao', 'Chih-Han', 'Simon', 'Anne', 'Ben', 'Joanne', 'Jason', 'Cristina', 'Noah', 'Pauline', 'Gautam', 'Ruchi', 'Ian', 'Chao', 'Chih-Kuan', 'Dima', 'Hui', 'Han', 'Huili', 'Jian-Huan', 'Liangliang', 'Meng-Yun', 'Si-Chong', 'Shi-Peng', 'Xiaoshu', 'Ying-Jiun', 'Yong-Liang', 'Yuxin', 'Lei', 'Yong-Sheng', 'Olga', 'Julia', 'Douglas', 'Luis-Miguel', 'Yin', 'Dylan', 'Rachel', 'Jinmyung', 'Sungho', 'Seung', 'Mathilde', 'Villy', 'Danielle', 'Pascal-Antoine', 'Zofia', 'Chengjin', 'Emilio', 'Pablo', 'Alyssa', 'Donald', 'Alice', 'Julien', 'Lauren', 'Lydia', 'Garry', 'Courtney', 'Aldo', 'Timo', 'Stella', 'Dov', 'Adriana', 'Roeland', 'Camille', 'Filipa', 'Raelene', 'Shelley', 'Catherine', 'Clayton', 'Anton', 'Erika', 'Sinead', 'Long-Gang', 'Laurence', 'Till', 'Manuela', 'Martin', 'Johan', 'Tad', 'Rhiannon', 'Anastasia', 'Cristian', 'Savel', 'Gemma', 'Vinicius', 'Cecile', 'Leonardo', 'Barnabas', 'Joshua', 'Marcia', 'Eve', 'Kalina', 'Wayne', 'Nicola', 'Emanuela', 'Teotonio', 'Johannes', 'Wanda', 'Marinrs', 'Sylvia', 'Marianne', 'Marjolein', 'Annelies', 'Pierre', 'Richarda', 'Linda', 'Franciska', 'Caroli', 'William', 'Lylah', 'Steven', 'Israel', 'Wojciech', 'Niv', 'Felix', 'Francisco', 'Qi', 'Helene', 'Rachael', 'Romain', 'Aisling', 'Frederick', 'Lianggong', 'Solomon', 'Annise', 'Margo', 'Xiaoli', 'Aine', 'Nathan', 'Liliya', 'Gbadamassi', 'Petr', 'Aurelien', 'Claire', 'Vinson', 'Louis', 'Enzai', 'Yanjun', 'Cheng-Guo', 'Leandro', 'Melodie', 'Sebastia ...

# %%
print("There are {} unique names".format(len(hashmap.keys())))
# Out:
# There are 1485 unique names

# %%
import json
import requests
# Example of API output
requests.get(url='https://api.genderize.io/?name=' + 'tanya').content
# Out:
# b'{"name":"tanya","gender":"female","probability":1,"count":960}'

# %%
# Commented sending requests to genderize API
#for name in hashmap.keys(): 
#    hashmap[name] = requests.get(url='https://api.genderize.io/?name=' + name.lower()).content

# %%
print(hashmap)
# Out:
# {'Jessica': 17, 'Luis': 5, 'Tomoyuki': 1, 'Andre': 3, 'Peter': 59, 'Dean': 1, 'Vanessa': 2, 'Michelle': 3, 'Anurag': 1, 'Ken': 10, 'Dirk': 4, 'Masahiro': 1, 'Christina': 3, 'Marcelo': 2, 'Susanne': 4, 'Patrick': 9, 'Diogo': 1, 'Arnaud': 1, 'Christoffer': 1, 'Joerg': 3, 'Helen': 6, 'Adam': 14, 'Hamid': 1, 'Eric': 18, 'Daniel': 55, 'Maximilian': 2, 'Jacob': 3, 'Andrew': 43, 'David': 115, 'Maria': 22, 'Florian': 4, 'Karie': 1, 'Diego': 5, 'Isabel': 3, 'Priyanga': 5, 'Roberto': 10, 'Tomotsune': 1, 'Aitor': 1, 'Francis': 4, 'Sarah': 20, 'Mette': 2, 'Marti': 2, 'Matthew': 42, 'Thomas': 56, 'Weston': 1, 'Sonia': 6, 'Dvir': 1, 'Patricia': 11, 'Yimen': 1, 'Gerardo': 1, 'Miguel': 9, 'Alicia': 3, 'Hector': 6, 'Jonathan': 48, 'Xavier': 4, 'Jennifer': 27, 'Paula': 6, 'Samuel': 6, 'Sonya': 1, 'Marie': 1, 'Gabriel': 4, 'Willem': 1, 'Amy': 31, 'Colin': 1, 'Tal': 6, 'Jose': 14, 'Ranen': 1, 'Eliran': 1, 'Sandro': 1, 'Benura': 1, 'Benedicte': 1, 'Ruxandra': 1, 'Guy': 1, 'Sara': 3, 'Lander': 1, 'Robert': 86, 'Wenming': 1, 'Ida': 1, 'Liam': 3, 'Diane': 2, 'Andy': 9, 'EmilyClare': 1, 'Timothy': 4, 'Jesus': 3, 'Aabir': 1, 'Natalie': 7, 'Gyoergy': 1, 'Marion': 3, 'Shannon': 2, 'Nicholas': 13, 'Albert': 5, 'Allison': 3, 'Lewis': 2, 'Felipe': 1, 'Luke': 14, 'Ceres': 1, 'Frederic': 4, 'Louise': 3, 'Andres': 8, 'Mathieu': 5, 'Ronald': 6, 'Marinelle': 1, 'Jens': 4, 'Guillaume': 2, 'Kaitlin': 1, 'Virgile': 1, 'Mark': 48, 'Jeremy': 8, 'Michael': 65, 'Niko': 1, 'Abdelkader': 1, 'Kevin': 11, 'Boris': 4, 'James': 45, 'Edwige': 1, 'Maira': 1, 'Joscha': 1, 'Cassandra': 1, 'Alison': 9, 'Joseph': 31, 'Scott': 21, 'Miles': 1, 'Ali': 1, 'Reut': 1, 'Maud': 2, 'Massimo': 1, 'Shimon': 1, 'Yann': 1, 'Elvire': 1, 'Ricardo': 3, 'Gustavo': 2, 'Hawthorne': 1, 'Tracey': 2, 'Simeon': 1, 'Radika': 1, 'Shipra': 1, 'Maloyjo': 1, 'Jiang-Hui': 1, 'Clotilde': 1, 'Filip': 1, 'Dimitri': 1, 'Jay': 8, 'Ewan': 3, 'Tom': 12, 'Uddipta': 1, 'Eirin': 1, 'Tim': 30, 'Paul': 11, 'Benjamin': 10, 'Manuel': 7, 'Elizabeth': 18, 'Gionata': 1, 'Steffen': 1, 'Kate': 8, 'Maarten': 4, 'Carl': 2, 'Monika': 2, 'Folmer': 1, 'Katharina': 3, 'Russell': 2, 'Maxime': 3, 'Richard': 63, 'Bridget': 1, 'Michal': 4, 'Zoltan': 1, 'Filippo': 1, 'Veronique': 2, 'Stephanie': 6, 'Sandra': 4, 'Charlotte': 3, 'Selina': 1, 'Bethany': 2, 'Mariana': 1, 'Vincent': 13, 'Angela': 4, 'Kari': 2, 'Frank': 16, 'Travis': 1, 'Stefan': 2, 'Mario': 3, 'Jedediah': 1, 'Chris': 6, 'Jeffrey': 14, 'Lindell': 1, 'Kristin': 4, 'Emma': 8, 'Mollie': 1, 'Brian': 51, 'Bryan': 4, 'Calum': 1, 'Carissa': 1, 'Christopher': 14, 'Gregory': 32, 'Leone': 1, 'Annalis': 1, 'Nicolas': 13, 'Lars': 10, 'Yannick': 1, 'John': 93, 'Hannah': 1, 'Yvonne': 5, 'Frances': 1, 'Arne': 6, 'Phillip': 2, 'Rebecca': 17, 'Ulf': 1, 'Karin': 3, 'Romina': 1, 'Hugh': 4, 'Edward': 10, 'Falko': 1, 'Raymond': 1, 'Fernando': 2, 'Alexander': 9, 'Francesca': 1, 'Justin': 14, 'Kim': 5, 'Erin': 8, 'Meghan': 3, 'Brandon': 12, 'Ulrika': 1, 'Stefano': 1, 'Minh': 1, 'Pol': 1, 'Isabella': 1, 'Marta': 5, 'Marcel': 20, 'Andrea': 7, 'Pedro': 11, 'Tomas': 3, 'Gunnar': 1, 'Stephen': 23, 'Francesco': 1, 'Paola': 1, 'Raul': 2, 'Martha': 2, 'Max': 1, 'Adrian': 7, 'Santiago': 3, 'Laura': 27, 'Bruno': 2, 'Jane': 7, 'Lorenzo': 3, 'Renee': 2, 'Hugo': 4, 'Giovanni': 3, 'Ann': 1, 'Yosra': 1, 'Stotra': 1, 'Mahul': 1, 'Loic': 2, 'Juliette': 4, 'Thierry': 6, 'Chia-Hao': 1, 'Chih-Han': 1, 'Simon': 23, 'Anne': 12, 'Ben': 22, 'Joanne': 1, 'Jason': 28, 'Cristina': 2, 'Noah': 3, 'Pauline': 1, 'Gautam': 1, 'Ruchi': 1, 'Ian': 10, 'Chao': 1, 'Chih-Kuan': 1, 'Dima': 1, 'Hui': 1, 'Han': 3, 'Huili': 1, 'Jian-Huan': 1, 'Liangliang': 1, 'Meng-Yun': 1, 'Si-Chong': 1, 'Shi-Peng': 1, 'Xiaoshu': 1, 'Ying-Jiun': 1, 'Yong-Liang': 1, 'Yuxin': 1, 'Lei': 2, 'Yong-Sheng': 1, 'Olga': 5, 'Julia': 7, 'Douglas': 10, 'Luis-Miguel': 1, 'Yin': 1, 'Dylan': 8, 'Rachel': 6, 'Jinmyung': 1, 'Sungho': 1, 'Seung': 1, 'Mathilde': 1, 'Villy': 1, 'Danielle': 4, 'Pascal-Antoine': 1, 'Zofia': 2, 'Chengjin': 1, 'Emilio': 2, 'Pablo': 3, 'Alyssa': 2, ...

# %%
# Store current results to the file
# import json
# with open('data.json', 'w') as outfile:
#     json.dump(hashmap, outfile)

# %%
# Get results from file. Fix some names were not loaded because of requests limit reached
with open('data.json') as f:
    hashmap = json.load(f)

# %%
io27 = 0
for key in hashmap.keys():
    if hashmap[key] == '{"error":"Request limit reached"}':
        hashmap[key] = requests.get(url='https://api.genderize.io/?name=' + key.lower()).content
        io27 += 1
        print(io27)
        print(key)

# %%
with open('data_final.json') as f:
    hashmap = json.load(f)

# %%
data['author_gender'] = pd.Series(np.random.randn(len(data)), index=data.index)
data['editor_gender'] = pd.Series(np.random.randn(len(data)), index=data.index)
data.head(5)
# Out:
#    Unnamed: 0                                              title  \
# 1           2  The relative importance of trait vs. genetic d...
# 2           3  Test of biotic and abiotic correlates of latit...
# 3           4  Multi-trophic consequences of plant genetic va...
# 4           5  Parameterisation and validation of a resource ...
# 5           6  An Efficient Independence Sampler for Updating...
#
#                  type author_first_name author_last_name editor_first_name  \
# 1             ECOLOGY           Jessica          hoareau          Jonathan
# 2  JOURNAL OF ECOLOGY              Luis           morard          Jennifer
# 3             ECOLOGY              Luis             soul             James
# 4     ECOLOGY LETTERS          Tomoyuki          farrell              Liza
# 5  SYSTEMATIC BIOLOGY             Andre           grogan             Peter
#
#   editor_last_name               author_institution  \
# 1        Grabowski   University of California Davis
# 2              Lau  Universidad Autonoma de Yucatan
# 3           Cronin  Universidad Autonoma de Yucatan
# 4           Comita                              NaN
# 5           Foster            Heidelberg University
#
#            editor_institution  author_gender  editor_gender
# 1     Northeastern University      -0.090737      -0.072297
# 2   Michigan State University      -1.294677      -1.585269
# 3  Louisiana State University      -0.648089       0.220762
# 4             Yale University       0.425052      -0.728908
# 5     University of Edinburgh      -1.851933      -0.065474

# %%
for index, row in data.iterrows():
    for col_name, col_gender in [['editor_first_name', 'editor_gender'], ['author_first_name', 'author_gender']]:
        if row[col_name] in hashmap:
            curr_item = json.loads(hashmap[row[col_name]])

            if curr_item["gender"] == None:
                data[col_gender][index] = -1
            else: 
                p = curr_item["probability"]
                c = curr_item["count"]
                new_prob = (p*c + 2) / (p + 4)
                if new_prob > 0.85:
                    data[col_gender][index] = curr_item["gender"]
                else: data[col_gender][index] = -1
        else:
            print('Error. No name in hashmap')
            print(row)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Error. No name in hashmap
# Unnamed: 0                                                           32
# title                 Social living mitigates the costs of a chronic...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    E.
# author_last_name                                                  heard
# editor_first_name                                                 Marco
# editor_last_name                                         Festa-Bianchet
# author_institution                                           Penn State
# editor_institution                             University of Sherbrooke
# author_gender                                                 -0.147273
# editor_gender                                                      male
# Name: 31, dtype: object
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Error. No name in hashmap
# Unnamed: 0                                                           73
# title                 Disentangling the biogeography of ship biofoul...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    G.
# author_last_name                                                peoples
# editor_first_name                                           Marie-Josee
# editor_last_name                                                 Fortin
# author_institution                                                  NaN
# editor_institution                                University of Toronto
# author_gender                                                -0.0477614
# editor_gender                                                    female
# Name: 72, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          112
# title                 fuzzySim: applying fuzzy logic to binary simil...
# type                                   METHODS IN ECOLOGY AND EVOLUTION
# author_first_name                                                    A.
# author_last_name                                               thompson
# editor_first_name                                                Robert
# editor_last_name                                                 O'Hara
# author_institution                                                  NaN
# editor_institution                              Biodiversitat und Klima
# author_gender                                                  0.578732
# editor_gender                                                      male
# Name: 111, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          118
# title                 Biotic interactions mediate patterns of herbiv...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    I.
# author_last_name                                               pardikes
# editor_first_name                                                 Brody
# editor_last_name                                                 Sandel
# author_institution                                University of Iceland
# editor_institution                               Santa Clara University
# author_gender                                                   1.51635
# editor_gender                                                      male
# Name: 117, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          124
# title                 Drought tolerance as a driver of tropical fore...
# type                                                            ECOLOGY
# author_first_name                                                    M.
# author_last_name                                                 feller
# editor_first_name                                                Gordon
# editor_last_name                                                    Fox
# author_institution                          Chinese Academy of Sciences
# editor_institution                          University of South Florida
# author_gender                                                  0.017257
# editor_gender                                                      male
# Name: 123, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          136
# title                 Cophylogeny Reconstruction via an Approximate ...
# type                                                 SYSTEMATIC BIOLOGY
# author_first_name                                                    C.
# author_last_name                                             troscianko
# editor_first_name                                               Michael
# editor_last_name                                             Charleston
# author_institution                                                  NaN
# editor_institution                               University of Tasmania
# author_gender                                                 -0.460241
# editor_gender                                                      male
# Name: 135, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          227
# title                 Spring temperatures influence selection on bre...
# type                                                            ECOLOGY
# author_first_name                                                    E.
# author_last_name                                               veldhuis
# editor_first_name                                                  John
# editor_last_name                                                  Sauer
# author_institution                            Illinois State University
# editor_institution               USGS Patuxent Wildlife Research Center
# author_gender                                                 -0.746821
# editor_gender                                                      male
# Name: 226, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          228
# title                 Persistent sex-by-environment effects on offsp...
# type                                          JOURNAL OF ANIMAL ECOLOGY
# author_first_name                                                    E.
# author_last_name                                                 vieira
# editor_first_name                                                 Simon
# editor_last_name                                               Griffith
# author_institution                            Illinois State University
# editor_institution                                 Macquarie University
# author_gender                                                   2.30832
# editor_gender                                                      male
# Name: 227, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          296
# title                 To die or not to die: early warnings of tree d...
# type                                                 JOURNAL OF ECOLOGY
# author_first_name                                                    J.
# author_last_name                                                derelle
# editor_first_name                                                 David
# editor_last_name                                                 Gibson
# author_institution                            ARAID Institute Pirenaico
# editor_institution                         Southern Illinois University
# author_gender                                                   2.14205
# editor_gender                                                      male
# Name: 295, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          407
# title                 Connecting the Sequence-Space of Bacterial Sig...
# type                                    MOLECULAR BIOLOGY AND EVOLUTION
# author_first_name                                                    R.
# author_last_name                                                 teller
# editor_first_name                                                 Claus
# editor_last_name                                                  Wilke
# author_institution                                      Rice University
# editor_institution                                  University of Texas
# author_gender                                                 -0.399812
# editor_gender                                                      male
# Name: 406, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          426
# title                 Fungal symbionts maintain a rare plant populat...
# type                                                 JOURNAL OF ECOLOGY
# author_first_name                                                    Y.
# author_last_name                                                hoelker
# editor_first_name                                                Marcel
# editor_last_name                                          VanDerHeijden
# author_institution                             University of New Mexico
# editor_institution        Agroscope Reckenholz-Tanikon Research Station
# author_gender                                                0.00224814
# editor_gender                                                      male
# Name: 425, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          475
# title                 Effects of ocean acidification on Posidonia oc...
# type                                                 JOURNAL OF ECOLOGY
# author_first_name                                                    T.
# author_last_name                                        razafindratsima
# editor_first_name                                                 Brian
# editor_last_name                                               Silliman
# author_institution                                  Universite Paris 06
# editor_institution                                      Duke University
# author_gender                                                 -0.615712
# editor_gender                                                      male
# Name: 474, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          487
# title                 Energetic costs of mange in wolves estimated f...
# type                                                            ECOLOGY
# author_first_name                                                    P.
# author_last_name                                                 pintor
# editor_first_name                                                 Heiko
# editor_last_name                                                Wittmer
# author_institution          USGS Northern Rocky Mountain Science Center
# editor_institution                    Victoria University of Wellington
# author_gender                                                 -0.343885
# editor_gender                                                      male
# Name: 486, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          517
# title                 Deconstructing the relationships between phylo...
# type                                                            ECOLOGY
# author_first_name                                                    T.
# author_last_name                                                 finger
# editor_first_name                                              Jeannine
# editor_last_name                                         Cavender-Bares
# author_institution                                    McGill University
# editor_institution                              University of Minnesota
# author_gender                                                   2.02591
# editor_gender                                                    female
# Name: 516, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          541
# title                 Remotely sensed temperature and precipitation ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    V.
# author_last_name                                                 knauer
# editor_first_name                                                 David
# editor_last_name                                                 Currie
# author_institution                                                  NaN
# editor_institution                                 University of Ottawa
# author_gender                                                   -1.2261
# editor_gender                                                      male
# Name: 540, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          542
# title                 Toward Synthesizing Our Knowledge of Morpholog...
# type                                                 SYSTEMATIC BIOLOGY
# author_first_name                                                    T.
# author_last_name                                               sletvold
# editor_first_name                                                Thomas
# editor_last_name                                                   Near
# author_institution                           University of South Dakota
# editor_institution                                      Yale University
# author_gender                                                  0.027306
# editor_gender                                                      male
# Name: 541, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          568
# title                 Reassessing global change research priorities ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    E.
# author_last_name                                                  lange
# editor_first_name                                                Martin
# editor_last_name                                                  Sykes
# author_institution                   Autonomous University of Barcelona
# editor_institution                                      Lund University
# author_gender                                                  -1.84041
# editor_gender                                                      male
# Name: 567, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          573
# title                 Following the Footsteps of Chlamydial Gene Reg...
# type                                    MOLECULAR BIOLOGY AND EVOLUTION
# author_first_name                                                    D.
# author_last_name                                       bachmann-gagescu
# editor_first_name                                                 James
# editor_last_name                                              McInerney
# author_institution                                 University of Vienna
# editor_institution                                  Maynooth University
# author_gender                                                  -1.35321
# editor_gender                                                      male
# Name: 572, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          587
# title                 Propagule pressure in the presence of uncertai...
# type                                   METHODS IN ECOLOGY AND EVOLUTION
# author_first_name                                                    D.
# author_last_name                                              silvestro
# editor_first_name                                                Andrew
# editor_last_name                                                  Tatem
# author_institution                    University of Toronto Scarborough
# editor_institution                            University of Southampton
# author_gender                                                  0.486662
# editor_gender                                                      male
# Name: 586, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          601
# title                 Biodiversity mediates top-down control in eelg...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    J.
# author_last_name                                                 dooley
# editor_first_name                                                 Boris
# editor_last_name                                                   Worm
# author_institution                 Virginia Institute of Marine Science
# editor_institution                                 Dalhousie University
# author_gender                                                  0.405539
# editor_gender                                                      male
# Name: 600, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          625
# title                 Spatial overlap in a solitary carnivore: suppo...
# type                                          JOURNAL OF ANIMAL ECOLOGY
# author_first_name                                                    L.
# author_last_name                                               mcdonald
# editor_first_name                                                  Anne
# editor_last_name                                                 Loison
# author_institution                                             Panthera
# editor_institution                                 Universite de Savoie
# author_gender                                                -0.0107257
# editor_gender                                                    female
# Name: 624, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          628
# title                 Using multiple imputation to estimate missing ...
# type                                   METHODS IN ECOLOGY AND EVOLUTION
# author_first_name                                                    E.
# author_last_name                                               anderson
# editor_first_name                                                Jarrod
# editor_last_name                                               Hadfield
# author_institution                                     Trent University
# editor_institution                              University of Edinburgh
# author_gender                                                   1.53451
# editor_gender                                                      male
# Name: 627, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          638
# title                 Eutrophication triggers contrasting multilevel...
# type                                                            ECOLOGY
# author_first_name                                                    W.
# author_last_name                                                bennett
# editor_first_name                                                Joseph
# editor_last_name                                                 Yavitt
# author_institution                                University of Antwerp
# editor_institution                                   Cornell University
# author_gender                                                   -1.0891
# editor_gender                                                      male
# Name: 637, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          648
# title                 Fire evolution in the radioactive forests of U...
# type                                              ECOLOGICAL MONOGRAPHS
# author_first_name                                                    N.
# author_last_name                                                gorsich
# editor_first_name                                                 Aimee
# editor_last_name                                                Classen
# author_institution                     Institute Pierre & Simon Laplace
# editor_institution                              University of Tennessee
# author_gender                                                  0.186793
# editor_gender                                                    female
# Name: 647, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          710
# title                 Locally adapted traits maintained in the face ...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    S.
# author_last_name                                                  tabak
# editor_first_name                                                  Jane
# editor_last_name                                                   Hill
# author_institution                            Colorado State University
# editor_institution                                   University of York
# author_gender                                                   1.48694
# editor_gender                                                    female
# Name: 709, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          713
# title                 Estimating where and how animals travel: an op...
# type                                                            ECOLOGY
# author_first_name                                                    C.
# author_last_name                                                 sunday
# editor_first_name                                              Nicholas
# editor_last_name                                                Gotelli
# author_institution                 National Zoological Park Front Royal
# editor_institution                                University of Vermont
# author_gender                                                   1.50637
# editor_gender                                                      male
# Name: 712, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          714
# title                 Unravelling the annual cycle in a migratory an...
# type                                          JOURNAL OF ANIMAL ECOLOGY
# author_first_name                                                    D.
# author_last_name                                             pellegrini
# editor_first_name                                                   Tim
# editor_last_name                                                Coulson
# author_institution                                 University of Guelph
# editor_institution                                 University of Oxford
# author_gender                                                   1.50428
# editor_gender                                                      male
# Name: 713, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                            718
# title                 The Phylogenetic Likelihood Library
# type                                   SYSTEMATIC BIOLOGY
# author_first_name                                      T.
# author_last_name                                 catarino
# editor_first_name                                   Peter
# editor_last_name                                   Foster
# author_institution                  Heidelberg University
# editor_institution                University of Edinburgh
# author_gender                                   -0.655767
# editor_gender                                        male
# Name: 717, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          725
# title                 Quantifying diet breadth through ordination of...
# type                                                            ECOLOGY
# author_first_name                                                    J.
# author_last_name                                               videvall
# editor_first_name                                                Helene
# editor_last_name                                                 Wagner
# author_institution                              University of Tennessee
# editor_institution                                University of Toronto
# author_gender                                                 -0.854039
# editor_gender                                                    female
# Name: 724, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                        832
# title                 The Root of Flowering Plants and Total Evidence
# type                                               SYSTEMATIC BIOLOGY
# author_first_name                                                  V.
# author_last_name                                                 chao
# editor_first_name                                              Edward
# editor_last_name                                                Susko
# author_institution                                                NaN
# editor_institution                               Dalhousie University
# author_gender                                                0.407765
# editor_gender                                                    male
# Name: 831, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          892
# title                 Cohort variation in individual body mass dissi...
# type                                              ECOLOGICAL MONOGRAPHS
# author_first_name                                                    S.
# author_last_name                                            van wijlick
# editor_first_name                                                 Arpat
# editor_last_name                                                  Ozgul
# author_institution                                 University of Tromso
# editor_institution                                 University of Zurich
# author_gender                                                  -1.49524
# editor_gender                                                  0.685374
# Name: 891, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          926
# title                 Seasonality and nitrogen supply modify carbon ...
# type                                                            ECOLOGY
# author_first_name                                                    N.
# author_last_name                                                  plard
# editor_first_name                                                Joseph
# editor_last_name                                                 Yavitt
# author_institution          Swedish University of Agricultural Sciences
# editor_institution                                   Cornell University
# author_gender                                                  -1.47548
# editor_gender                                                      male
# Name: 925, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          940
# title                 Invaders do not require high resource levels t...
# type                                                            ECOLOGY
# author_first_name                                                    J.
# author_last_name                                                 janzen
# editor_first_name                                                Daniel
# editor_last_name                                               Laughlin
# author_institution                                  Syracuse University
# editor_institution                                University of Waikato
# author_gender                                                 -0.554377
# editor_gender                                                      male
# Name: 939, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          942
# title                 Tree of Life Reveals Clock-Like Speciation and...
# type                                    MOLECULAR BIOLOGY AND EVOLUTION
# author_first_name                                                    S.
# author_last_name                                              schneider
# editor_first_name                                                  Emma
# editor_last_name                                                Teeling
# author_institution                                    Temple University
# editor_institution                            University College Dublin
# author_gender                                                   3.01706
# editor_gender                                                    female
# Name: 941, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          943
# title                 The influence of climate on avian nest constru...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    C.
# author_last_name                                          zambrano-vega
# editor_first_name                                                Katrin
# editor_last_name                                          Bohning-Gaese
# author_institution                               University of Adelaide
# editor_institution    Senckenberg Biodiversity and Climate Research ...
# author_gender                                                  0.720357
# editor_gender                                                    female
# Name: 942, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          957
# title                 Link flexibility: evidence for environment-dep...
# type                                                            ECOLOGY
# author_first_name                                                    D.
# author_last_name                                                 joseph
# editor_first_name                                               William
# editor_last_name                                                 Snyder
# author_institution                                   University of Hull
# editor_institution                          Washington State University
# author_gender                                                  -1.56718
# editor_gender                                                      male
# Name: 956, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          975
# title                 An allometric approach to quantify the extinct...
# type                                                            ECOLOGY
# author_first_name                                                    J.
# author_last_name                                                   roll
# editor_first_name                                                Donald
# editor_last_name                                                 Strong
# author_institution                                   Radboud University
# editor_institution                       University of California Davis
# author_gender                                                   1.10856
# editor_gender                                                      male
# Name: 974, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                          982
# title                 State-space modeling to support management of ...
# type                                              ECOLOGICAL MONOGRAPHS
# author_first_name                                                    N.
# author_last_name                                               bartlett
# editor_first_name                                                 Aaron
# editor_last_name                                                Ellison
# author_institution                            Colorado State University
# editor_institution                                       Harvard Forest
# author_gender                                                  0.404893
# editor_gender                                                      male
# Name: 981, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1004
# title                 A guide to Bayesian model selection for ecolog...
# type                                              ECOLOGICAL MONOGRAPHS
# author_first_name                                                    M.
# author_last_name                                                   choi
# editor_first_name                                                 Aaron
# editor_last_name                                                Ellison
# author_institution                            Colorado State University
# editor_institution                                       Harvard Forest
# author_gender                                                 -0.148294
# editor_gender                                                      male
# Name: 1003, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1010
# title                 Unravelling the relative roles of top-down and...
# type                                                            ECOLOGY
# author_first_name                                                    C.
# author_last_name                                                  keagy
# editor_first_name                                                  John
# editor_last_name                                                Arnould
# author_institution                   British Antarctic Survey Cambridge
# editor_institution                                    Deakin University
# author_gender                                                 -0.602837
# editor_gender                                                      male
# Name: 1009, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1055
# title                 Assessing European ecosystem stability to drou...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    E.
# author_last_name                                                     yu
# editor_first_name                                                  Nick
# editor_last_name                                                  Isaac
# author_institution                                                  NaN
# editor_institution                     Centre for Ecology and Hydrology
# author_gender                                                 -0.166883
# editor_gender                                                      male
# Name: 1054, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1069
# title                 Fitness reduction for uncooperative fig wasps ...
# type                                                            ECOLOGY
# author_first_name                                                    K.
# author_last_name                                                simpson
# editor_first_name                                                 David
# editor_last_name                                                 Holway
# author_institution                                   Harvard University
# editor_institution                   University of California San Diego
# author_gender                                                  0.810329
# editor_gender                                                      male
# Name: 1068, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1081
# title                 Climate tolerances and trait choices shape con...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    G.
# author_last_name                                zechmeister-boltenstern
# editor_first_name                                                  Karl
# editor_last_name                                                  Evans
# author_institution                   University of California Riverside
# editor_institution                              University of Sheffield
# author_gender                                                  0.515589
# editor_gender                                                      male
# Name: 1080, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1088
# title                 Relatively stable response of fruiting stage t...
# type                                                            ECOLOGY
# author_first_name                                                    L.
# author_last_name                                                veyrier
# editor_first_name                                                Daniel
# editor_last_name                                               Metcalfe
# author_institution                          Chinese Academy of Sciences
# editor_institution          Swedish University of Agricultural Sciences
# author_gender                                                  -1.29777
# editor_gender                                                      male
# Name: 1087, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1093
# title                 Genetic diversity affects the strength of popu...
# type                                                            ECOLOGY
# author_first_name                                                    D.
# author_last_name                                                  brown
# editor_first_name                                               Lorenzo
# editor_last_name                                              Ciannelli
# author_institution               California state University Long Beach
# editor_institution                              Oregon State University
# author_gender                                                 -0.366294
# editor_gender                                                      male
# Name: 1092, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1169
# title                 Productivity and species richness in longleaf ...
# type                                                            ECOLOGY
# author_first_name                                                    L.
# author_last_name                                                 farrer
# editor_first_name                                               Anthony
# editor_last_name                                                D'Amato
# author_institution            Joseph W Jones Ecological Research Center
# editor_institution                                University of Vermont
# author_gender                                                 -0.663339
# editor_gender                                                      male
# Name: 1168, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1180
# title                 Bees use honest floral signals as indicators o...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    A.
# author_last_name                                              capellini
# editor_first_name                                               Rebecca
# editor_last_name                                                  Irwin
# author_institution                                 University of Zurich
# editor_institution                                    Dartmouth College
# author_gender                                                   0.62414
# editor_gender                                                    female
# Name: 1179, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                        1218
# title                 Global aerial flyways allow efficient travelling
# type                                                   ECOLOGY LETTERS
# author_first_name                                                   B.
# author_last_name                                               moeller
# editor_first_name                                                 Ryan
# editor_last_name                                                Norris
# author_institution                 Max Planck Institute of Ornithology
# editor_institution                                University of Guelph
# author_gender                                                 -1.58285
# editor_gender                                                     male
# Name: 1217, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1370
# title                 Changes in plant, soil, and microbes in a typi...
# type                                              ECOLOGICAL MONOGRAPHS
# author_first_name                                                    N.
# author_last_name                                               esquerre
# editor_first_name                                                 Aimee
# editor_last_name                                                Classen
# author_institution                            University of Agriculture
# editor_institution                              University of Tennessee
# author_gender                                                  0.387679
# editor_gender                                                    female
# Name: 1369, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1384
# title                 The siren song of a sticky plant: Columbines p...
# type                                                            ECOLOGY
# author_first_name                                                    E.
# author_last_name                                                chapman
# editor_first_name                                                 Brian
# editor_last_name                                                 Inouye
# author_institution                       University of California Davis
# editor_institution                             Florida State University
# author_gender                                                  0.952688
# editor_gender                                                      male
# Name: 1383, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1442
# title                 Sport science for salmon and other species: ec...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    B.
# author_last_name                                                 yeager
# editor_first_name                                                 Mikko
# editor_last_name                                                  Heino
# author_institution               University of California Santa Barbara
# editor_institution                                 University of Bergen
# author_gender                                                   1.43323
# editor_gender                                                      male
# Name: 1441, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1480
# title                 Geographic extent and variation of a coral ree...
# type                                                            ECOLOGY
# author_first_name                                                    T.
# author_last_name                                               matthias
# editor_first_name                                                Steven
# editor_last_name                                                 Morgan
# author_institution                        Wildlife Conservation Society
# editor_institution                             Bodega Marine Laboratory
# author_gender                                                  0.980918
# editor_gender                                                      male
# Name: 1479, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1491
# title                 Exploring the spatially explicit predictions o...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    D.
# author_last_name                                               hardesty
# editor_first_name                                                  Jose
# editor_last_name                                            Diniz-Filho
# author_institution                                College of Charleston
# editor_institution                        Universidade Federal de Goias
# author_gender                                                   1.14915
# editor_gender                                                      male
# Name: 1490, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1528
# title                 Avoiding the crowds: the evolution of plastic ...
# type                                                 JOURNAL OF ECOLOGY
# author_first_name                                                    C.
# author_last_name                                               mariotti
# editor_first_name                                               Roberto
# editor_last_name                                         Salguero-Gomez
# author_institution                                 Princeton University
# editor_institution                              University of Sheffield
# author_gender                                                   1.01071
# editor_gender                                                      male
# Name: 1527, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1529
# title                 Statistical modelling of annual variation for ...
# type                                   METHODS IN ECOLOGY AND EVOLUTION
# author_first_name                                                    C.
# author_last_name                                                  menke
# editor_first_name                                                  Satu
# editor_last_name                                                 Ramula
# author_institution                                 Princeton University
# editor_institution                                  University of Turku
# author_gender                                                  -2.32375
# editor_gender                                                    female
# Name: 1528, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1530
# title                 Opportunities and challenges of Integral Proje...
# type                                          JOURNAL OF ANIMAL ECOLOGY
# author_first_name                                                    C.
# author_last_name                                                 moreno
# editor_first_name                                               Roberto
# editor_last_name                                         Salguero-Gomez
# author_institution                                 Princeton University
# editor_institution                              University of Sheffield
# author_gender                                                   -1.4235
# editor_gender                                                      male
# Name: 1529, dtype: object
# Error. No name in hashmap
# ...
# author_gender                                                -0.0220238
# editor_gender                                                      male
# Name: 1753, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1786
# title                 Diversity enhances carbon storage in tropical ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    L.
# author_last_name                                                   ives
# editor_first_name                                                Thomas
# editor_last_name                                                Hickler
# author_institution                                Wageningen University
# editor_institution                 Goethe Universitat Frankfurt am Main
# author_gender                                                 -0.793309
# editor_gender                                                      male
# Name: 1785, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1838
# title                 Between-taxon matching of common and rare spec...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    C.
# author_last_name                                                  hertz
# editor_first_name                                                  Gary
# editor_last_name                                             Mittelbach
# author_institution                           Queen's University Belfast
# editor_institution                            Michigan State University
# author_gender                                                   1.44148
# editor_gender                                                      male
# Name: 1837, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1897
# title                 Community assembly on isolated islands: macroe...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                               schlicht
# editor_first_name                                                Robert
# editor_last_name                                               Ricklefs
# author_institution                    University of California Berkeley
# editor_institution                   University of Missouri Saint Louis
# author_gender                                                 -0.149977
# editor_gender                                                      male
# Name: 1896, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1912
# title                 Scaling mangrove aboveground biomass from site...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                                   liow
# editor_first_name                                                 David
# editor_last_name                                                 Currie
# author_institution                    University Federal Santa Catarina
# editor_institution                                 University of Ottawa
# author_gender                                                   1.80871
# editor_gender                                                      male
# Name: 1911, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         1931
# title                 Bacterial community response to changes in a t...
# type                                                            ECOLOGY
# author_first_name                                                    J.
# author_last_name                                                   liao
# editor_first_name                                                 Ellen
# editor_last_name                                                vanDonk
# author_institution                              University of Jyvaskyla
# editor_institution                     Netherlands Institute of Ecology
# author_gender                                                 -0.929091
# editor_gender                                                    female
# Name: 1930, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2004
# title                 Metabolic dependence of phytoplankton species ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                                freyman
# editor_first_name                                                  Gary
# editor_last_name                                             Mittelbach
# author_institution                                 University Republica
# editor_institution                            Michigan State University
# author_gender                                                  0.129088
# editor_gender                                                      male
# Name: 2003, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2014
# title                 Does phylogeographical structure relate to cli...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    M.
# author_last_name                                                 dallas
# editor_first_name                                                 Linda
# editor_last_name                                               Beaumont
# author_institution                             University of Valladolid
# editor_institution                                 Macquarie University
# author_gender                                                 -0.173717
# editor_gender                                                    female
# Name: 2013, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                  2019
# title                        What Is Speciation?
# type                               PLOS GENETICS
# author_first_name                             B.
# author_last_name                          scarpa
# editor_first_name                           Ivan
# editor_last_name                           Matic
# author_institution           Universite Montreal
# editor_institution    University Paris Descartes
# author_gender                           0.108665
# editor_gender                               male
# Name: 2018, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2057
# title                 Can people change the ecological rules that ap...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                               landgraf
# editor_first_name                                                Jeremy
# editor_last_name                                                   Kerr
# author_institution                                   Charles University
# editor_institution                                 University of Ottawa
# author_gender                                                  0.932871
# editor_gender                                                      male
# Name: 2056, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2106
# title                 Analysis of stable states in global savannas: ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                                 hansen
# editor_first_name                                               Niklaus
# editor_last_name                                             Zimmermann
# author_institution                                      Yale University
# editor_institution                     Swiss Federal Research Institute
# author_gender                                                  0.324901
# editor_gender                                                      male
# Name: 2105, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2216
# title                 Crop rotational diversity enhances belowground...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    L.
# author_last_name                                              maldonado
# editor_first_name                                                 David
# editor_last_name                                                 Hooper
# author_institution                          University of New Hampshire
# editor_institution                        Western Washington University
# author_gender                                                   0.24324
# editor_gender                                                      male
# Name: 2215, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2247
# title                 A framework for integrating thermal biology in...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    K.
# author_last_name                                                  amrit
# editor_first_name                                                  Mary
# editor_last_name                                               O'Connor
# author_institution                               University of Colorado
# editor_institution                       University of British Columbia
# author_gender                                                  0.783784
# editor_gender                                                    female
# Name: 2246, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2250
# title                 Evaluating the effects of pollinator-mediated ...
# type                                                    ECOLOGY LETTERS
# author_first_name                                                    C.
# author_last_name                                                     wu
# editor_first_name                                            Jose Maria
# editor_last_name                                                  Gomez
# author_institution                   University of the Balearic Islands
# editor_institution                               Universidad De Granada
# author_gender                                                  0.334532
# editor_gender                                                      male
# Name: 2249, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2258
# title                 Pan-tropical hinterland forests: mapping minim...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    A.
# author_last_name                                               noonburg
# editor_first_name                                                Thomas
# editor_last_name                                              Gillespie
# author_institution                               University of Maryland
# editor_institution                                     Emory University
# author_gender                                                 -0.296601
# editor_gender                                                      male
# Name: 2257, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2282
# title                 Simulation of the phenological development of ...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    L.
# author_last_name                                                 murray
# editor_first_name                                                Martin
# editor_last_name                                                  Sykes
# author_institution                                Wageningen University
# editor_institution                                      Lund University
# author_gender                                                 -0.487177
# editor_gender                                                      male
# Name: 2281, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2409
# title                 Critical-weight-range marsupials in northern A...
# type                                    GLOBAL ECOLOGY AND BIOGEOGRAPHY
# author_first_name                                                    J.
# author_last_name                                              ten brink
# editor_first_name                                                 Erica
# editor_last_name                                             Fleischman
# author_institution                                                  NaN
# editor_institution                       University of California Davis
# author_gender                                                 0.0901312
# editor_gender                                                    female
# Name: 2408, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2422
# title                 Interspecific associations in seed arrival and...
# type                                                            ECOLOGY
# author_first_name                                                    S.
# author_last_name                                                  burla
# editor_first_name                                                 Peter
# editor_last_name                                                  Adler
# author_institution                                                  NaN
# editor_institution                                Utah State University
# author_gender                                                   1.37466
# editor_gender                                                      male
# Name: 2421, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2429
# title                 Effects of spatial plant-soil feedback heterog...
# type                                                 JOURNAL OF ECOLOGY
# author_first_name                                                    E.
# author_last_name                                                  alroy
# editor_first_name                                                   Amy
# editor_last_name                                                 Austin
# author_institution                     Netherlands Institute of Ecology
# editor_institution                           University of Buenos Aires
# author_gender                                                  0.703213
# editor_gender                                                    female
# Name: 2428, dtype: object
# Error. No name in hashmap
# Unnamed: 0                                                         2499
# title                 Recombination Rate Variation, Hitchhiking, and...
# type                                    MOLECULAR BIOLOGY AND EVOLUTION
# author_first_name                                                    M.
# author_last_name                                                 jasper
# editor_first_name                                               Brandon
# editor_last_name                                                   Gaut
# author_institution     Virginia Polytechni Institute & State University
# editor_institution                      University of California Irvine
# author_gender                                                   1.16005
# editor_gender                                                      male
# Name: 2498, dtype: object

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# Now let's cleanup and set the probabilities + perform (cp + 4 / p + 2) normalization

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 1           2  The relative importance of trait vs. genetic d...
# 2           3  Test of biotic and abiotic correlates of latit...
# 3           4  Multi-trophic consequences of plant genetic va...
# 4           5  Parameterisation and validation of a resource ...
# 5           6  An Efficient Independence Sampler for Updating...
#
#                  type author_first_name author_last_name editor_first_name  \
# 1             ECOLOGY           Jessica          hoareau          Jonathan
# 2  JOURNAL OF ECOLOGY              Luis           morard          Jennifer
# 3             ECOLOGY              Luis             soul             James
# 4     ECOLOGY LETTERS          Tomoyuki          farrell              Liza
# 5  SYSTEMATIC BIOLOGY             Andre           grogan             Peter
#
#   editor_last_name               author_institution  \
# 1        Grabowski   University of California Davis
# 2              Lau  Universidad Autonoma de Yucatan
# 3           Cronin  Universidad Autonoma de Yucatan
# 4           Comita                              NaN
# 5           Foster            Heidelberg University
#
#            editor_institution author_gender editor_gender
# 1     Northeastern University        female          male
# 2   Michigan State University          male        female
# 3  Louisiana State University          male          male
# 4             Yale University            -1        female
# 5     University of Edinburgh          male          male

# %%
print("Ratio of female / male in authors", len(data[data['author_gender'] == "female"]) / len(data[data['author_gender'] == "male"]))
# Out:
# Ratio of female / male in authors 0.62004662004662

# %%
print("Ratio of female / male in editors", len(data[data['editor_gender'] == "female"]) / len(data[data['editor_gender'] == "male"]))
# Out:
# Ratio of female / male in editors 0.2918502202643172
