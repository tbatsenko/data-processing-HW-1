# %% [markdown]
# # Analysing gender in ecology publications

# %% [markdown]
# ### Loading the data

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import csv
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# Let us load the data as a pandas dataframe.

# %%
data = pd.read_csv("new_journals_data.csv", sep = ",")
len(data)
# Out:
# 2532

# %% [markdown]
# ### Exploring the data
# Now take a look at the dataset and its features:

# %%
data.head(5)
# Out:
#    Unnamed: 0                                                 TI  \
# 0           1  Ecology Letters, and Transparency and Openness...
# 1           2  The relative importance of trait vs. genetic d...
# 2           3  Test of biotic and abiotic correlates of latit...
# 3           4  Multi-trophic consequences of plant genetic va...
# 4           5  Parameterisation and validation of a resource ...
#
#                    SO LeadAuthorFirst LeadAuthorLast LeadInitOnly  \
# 0     ECOLOGY LETTERS             NaN        daniels           no
# 1             ECOLOGY         Jessica        hoareau           no
# 2  JOURNAL OF ECOLOGY            Luis         morard           no
# 3             ECOLOGY            Luis           soul           no
# 4     ECOLOGY LETTERS        Tomoyuki        farrell           no
#
#   first.gender.manual first.gender first.gender.manual.method EditorFirst  \
# 0                 NaN          NaN                        NaN         NaN
# 1              female       female                        NaN    Jonathan
# 2                male         male                        NaN    Jennifer
# 3                male         male                        NaN       James
# 4                 NaN          NaN                        NaN        Liza
#
#   EditorLast editor.gender.manual                       FirstInst2  \
# 0        NaN                  NaN                              NaN
# 1  Grabowski                 male   University of California Davis
# 2        Lau               female  Universidad Autonoma de Yucatan
# 3     Cronin                 male  Universidad Autonoma de Yucatan
# 4     Comita               female                              NaN
#
#            Editor.Institution
# 0                         NaN
# 1     Northeastern University
# 2   Michigan State University
# 3  Louisiana State University
# 4             Yale University

# %%
data.dtypes
# Out:
# Unnamed: 0                     int64
# TI                            object
# SO                            object
# LeadAuthorFirst               object
# LeadAuthorLast                object
# LeadInitOnly                  object
# first.gender.manual           object
# first.gender                  object
# first.gender.manual.method    object
# EditorFirst                   object
# EditorLast                    object
# editor.gender.manual          object
# FirstInst2                    object
# Editor.Institution            object
# dtype: object

# %% [markdown]
# ### Clear the data from fields we don't need
# Delete all data about gender

# %%
data = data.drop(columns=["LeadInitOnly",
                             "first.gender.manual",
                             "first.gender",
                             "first.gender.manual.method",
                             "editor.gender.manual",
                            ])

# %% [markdown]
# ### Fix columns naming
# For the simplicity let's fix the naming to a more logical one

# %%
data.rename(columns={'Unnamed': 'index',
                     'TI':'title',
                     'SO':'type',
                     'LeadAuthorFirst':'author_first_name',
                     'LeadAuthorLast':'author_last_name',
                     'EditorFirst':'editor_first_name',
                     'EditorLast':'editor_last_name',
                     'FirstInst2':'author_institution',
                     'Editor.Institution':'editor_institution',
                    }, 
                 inplace=True)

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# title                 object
# type                  object
# author_first_name     object
# author_last_name      object
# editor_first_name     object
# editor_last_name      object
# author_institution    object
# editor_institution    object
# dtype: object

# %% [markdown]
# Take only those records where author_first_name & editor_first_name are valid

# %%
len(data)
# Out:
# 2532

# %%
data = data[data['author_first_name'].notnull()]
# data = data[not(len(data['author_first_name']) == 2 and data['author_first_name'][1] == ".")]
data = data[data['editor_first_name'].notnull()]
# data = data[len(data['editor_first_name']) > 2 and data['editor_first_name'][1] != "."]

# %%
len(data)
# Out:
# 2425

# %% [markdown]
# ### TODO: label women or men using genderize.io API and (cp + 4 / p + 2) normalization

# %%
hashmap = {}
rows_to_del = []

indx = 0

for index, row in data.iterrows():
    if len(row['author_first_name']) == 2 and row['author_first_name'][1] == ".":
        rows_to_del.append(indx)
    elif row['author_first_name'] in hashmap:
        hashmap[row['author_first_name']] += 1
    else:
        hashmap[row['author_first_name']] = 1
    indx += 1

for index, row in data.iterrows():
    if len(row['editor_first_name']) == 2 and row['editor_first_name'][1] == ".":
        rows_to_del.append(indx)
    elif row['editor_first_name'] in hashmap:
        hashmap[row['editor_first_name']] += 1
    else:
        hashmap[row['editor_first_name']] = 1
    indx += 1

for idx in rows_to_del: 
    data.drop(data.index[[idx]])
print(hashmap.keys())
# Out:
# ['Andreas', 'Stuart', 'Bailey', 'Erfan', 'Madelon', 'Claus', 'Ronald', 'Henri', 'Jean-Benoist', 'Valeriano', 'Shuli', 'Bret', 'Thomas', 'Guarino', 'Kohtaro', 'Ge', 'Jon', 'Guray', 'Paul', 'Leanne', 'Mitch', 'Claude', 'Joana', 'Hai-Jing', 'Matthew', 'Sally', 'Imroze', 'Stephanie', 'Asier', 'Zdenka', 'Angie', 'Dominique', 'Benedicte', 'Xiao', 'Elisabeth', 'Andre', 'Niall', 'Jes', 'Arik', 'Joerg', 'Witawas', 'Jef', 'Romain', 'Clotilde', 'Vernon', 'Stan', 'Johanna', 'Christina', 'Christine', 'Arndt', 'Olga', 'Coleen', 'Dimitri', 'Lynette', 'Ramiro', 'Stefanie', 'Oriol', 'Junjie', 'Le', 'Sara', 'Li', 'Brian', 'Bruno', 'Hui-Ling', 'Annalis', 'Jesus', 'Jiangxiao', 'Benoit', 'Deli', 'Kai', 'Josef', 'Jordan', 'Miranda', 'Monika', 'Josep', 'Neus', 'Renee', 'Dylan', 'Joscha', 'Lucas', 'Kangchon', 'Emanuel', 'Carlos', 'Ali', 'Zhenying', 'Maxwell', 'Ruxandra', 'Liliane', 'Eric', 'Yazmin', 'DevinW.', 'Shimon', 'Irene', 'Matti', 'Gabriela', 'Gabriele', 'Lovisa', 'Laurence', 'Menno', 'Drew', 'Sin-Yeon', 'Evan', 'Helen', 'Xinqiang', 'Seth', 'Ignatius', 'Minus', 'Till', 'Mikkel', 'Kirsty', 'Faith', 'Taal', 'Varvara', 'Antoine', 'Samina', 'Derek', 'Musa', 'Romeo', 'William', 'Annelies', 'Katrin', 'Kellie', 'Corinna', 'Rocio', 'Nigel', 'Chao', 'Kiva', 'Lasse', 'Nicolas', 'Dorothee', 'Bridget', 'Viktoriia', 'Inger', 'Etienne', 'Sonia', 'Eike', 'Rebecca', 'Alexander', 'Maarten', 'Tetsuji', 'Rahel', 'Kalle', 'Goffredo', 'Natasha', 'Chloe', 'Craig', 'Adela', 'Colin', 'Gang', 'Sen', 'Eveline', 'Cassandra', 'Angela', 'Johannes', 'Holly', 'Sylvia', 'Selina', 'Christian', 'Inigo', 'Albert', 'Guojing', 'Erle', 'Long-Gang', 'Xingli', 'Bartholomew', 'Iain', 'Lynn', 'Olli-Matti', 'Ivar', 'Tadashi', 'Frederick', 'Lucy', 'Luca', 'Olivier', 'Qi', 'Shaopeng', 'Conrad', 'Kari', 'Lewis', 'Philippine', 'Itsumi', 'Bjorn', 'Bodil', 'Christoffer', 'Laszlo', 'Daven', 'Marko', 'Tamar', 'Anna', 'Russell', 'Xuehui', 'Christophe', 'Kadri', 'Kazuo', 'Holger', 'Aabir', 'Magdalena', 'Jose Maria', 'Hideki', 'Zhichun', 'Mahendra', 'Sydney', 'John', 'Mahasweta', 'Mathilde', 'Rui', 'Wakana', 'Courty', 'Shuxiao', 'Edgar', 'Trey', 'Ainhoa', 'Lindsey', 'Pramod', 'Guangchao', 'Veronica', 'Xiujuan', 'Naoto', 'Karen', 'Gunnar', 'Lauri', 'Lorraine', 'Forest', 'Xiao-Qin', 'Saurabh', 'Kerry', 'Tommaso', 'Shinicki', 'Vasco', 'Ofir', 'Hillary', 'Remington', 'Arnaud', 'Alexandru', 'Rachael', 'Alexandro', 'Alexandra', 'Yann', 'Alexandre', 'Yuseob', 'Elin', 'Yingying', 'Radika', 'Ignacio', 'Yingqin', 'Gautam', 'Ellie', 'Courtney', 'Virgile', 'Jeffrey', 'Yuxin', 'Zilong', 'Jerome', 'Wenming', 'Gabriel', 'Chisato', 'Kimberley', 'Marie-Josee', 'Steffen', 'Tracey', 'Yanjun', 'Minh', 'Gavin', 'Savel', 'Sarah', 'Satu', 'Sulaiman', 'Ricardo', 'Lorenzo', 'Petr', 'Shuang', 'Jiao-Lin', 'Philippe', 'Anais', 'Oscar', 'Maria-Jose', 'Zhongle', 'Ingvild', 'Krishna', 'Roberta', 'James', 'Nadja', 'Roberto', 'Alice', 'Ignasi', 'Emilio', 'Rudolf', 'Claudia', 'Art', 'Brenda', 'Michele', 'Alissa', 'Raquel', 'Liza', 'Zhi-Chao', 'Steven', 'Sybil', 'Stotra', 'Lindell', 'Ting', 'Ximing', 'Francoise', 'Tina', 'Ines', 'Susana', 'Lee', 'Lei', 'Len', 'Leo', 'Dave', 'Chris', 'Chia-Hao', 'Ikram', 'He', 'Remy', 'Neal', 'Alix', 'Remi', 'Corey', 'Renato', 'Guangxi', 'Weidong', 'Arpat', 'Lynna', 'Cameron', 'Wenwen', 'Marius', 'Hong', 'Uriel', 'Chandrasekhar', 'Kristy', 'Niko', 'Fei', 'Krista', 'Aaron', 'Sonya', 'Martha', 'Abraham', 'Shawn', 'Shurong', 'Niklaus', 'Qi-En', 'Shuai', 'Sjoerd', 'Hans', 'Elena', 'Barnabas', 'Aisling', 'Gionata', 'Sebastien', 'Jean', 'Limei', 'Marianne', 'Toni', 'Nadejda', 'Tony', 'Jose', 'Jinpu', 'Giedrius', 'Josh', 'Hector', 'Rony', 'Melissa', 'Nibedita', 'Audrey', 'Francisco', 'Andres', 'Donald', 'Blaise', 'Ewan', 'Andrei', 'Andrea', 'Serita', 'Ida', 'Emile', 'Charles', 'Xoaquin', 'Cristina', 'Emily', 'Ying-Jiun', 'Cecile', 'Jussi', 'Nadia', 'Alana', 'Raelene', 'Iker', 'Dan', 'Burt', 'Melinda', 'Xuli', 'Yoko', 'Wanda', 'Chiara', 'Janneke Hille', 'Yong-Sheng', 'Elaine', 'Zoltan', 'EmilyClare', 'Shis ...

# %%
print("There are {} unique names".format(len(hashmap.keys())))
# Out:
# There are 1485 unique names

# %%
import json
import requests
# Example of API output
requests.get(url='https://api.genderize.io/?name=' + 'tanya').content
# Out:
# '{"name":"ranen","gender":"male","probability":1,"count":1}'

# %%
for name in hashmap.keys(): 
    hashmap[name] = requests.get(url='https://api.genderize.io/?name=' + name.lower()).content

# %%
print(hashmap)
# Out:
# {'Andreas': '{"name":"andreas","gender":"male","probability":1,"count":1021}', 'Stuart': '{"name":"stuart","gender":"male","probability":0.99,"count":759}', 'Bailey': '{"name":"bailey","gender":"female","probability":0.85,"count":215}', 'Erfan': '{"name":"erfan","gender":"male","probability":1,"count":9}', 'Madelon': '{"name":"madelon","gender":"female","probability":1,"count":2}', 'Claus': '{"name":"claus","gender":"male","probability":0.88,"count":119}', 'Ronald': '{"name":"ronald","gender":"male","probability":1,"count":755}', 'Henri': '{"name":"henri","gender":"male","probability":0.98,"count":138}', 'Jean-Benoist': '{"name":"jean-benoist","gender":null}', 'Valeriano': '{"name":"valeriano","gender":"male","probability":1,"count":3}', 'Shuli': '{"name":"shuli","gender":"female","probability":0.88,"count":8}', 'Bret': '{"name":"bret","gender":"male","probability":0.99,"count":88}', 'Thomas': '{"name":"thomas","gender":"male","probability":1,"count":3753}', 'Guarino': '{"name":"guarino","gender":"male","probability":1,"count":1}', 'Kohtaro': '{"name":"kohtaro","gender":null}', 'Ge': '{"name":"ge","gender":"male","probability":0.61,"count":33}', 'Jon': '{"name":"jon","gender":"male","probability":1,"count":1790}', 'Guray': '{"name":"guray","gender":null}', 'Paul': '{"name":"paul","gender":"male","probability":1,"count":5931}', 'Leanne': '{"name":"leanne","gender":"female","probability":1,"count":621}', 'Mitch': '{"name":"mitch","gender":"male","probability":0.93,"count":358}', 'Claude': '{"name":"claude","gender":"male","probability":0.81,"count":327}', 'Joana': '{"name":"joana","gender":"female","probability":0.99,"count":257}', 'Hai-Jing': '{"name":"hai-jing","gender":null}', 'Matthew': '{"name":"matthew","gender":"male","probability":1,"count":3338}', 'Sally': '{"name":"sally","gender":"female","probability":0.99,"count":1136}', 'Imroze': '{"name":"imroze","gender":null}', 'Stephanie': '{"name":"stephanie","gender":"female","probability":1,"count":4114}', 'Asier': '{"name":"asier","gender":"male","probability":0.91,"count":23}', 'Zdenka': '{"name":"zdenka","gender":"female","probability":1,"count":23}', 'Angie': '{"name":"angie","gender":"female","probability":1,"count":1495}', 'Dominique': '{"name":"dominique","gender":"female","probability":0.69,"count":689}', 'Benedicte': '{"name":"benedicte","gender":"female","probability":1,"count":42}', 'Xiao': '{"name":"xiao","gender":"female","probability":0.74,"count":102}', 'Elisabeth': '{"name":"elisabeth","gender":"female","probability":1,"count":570}', 'Andre': '{"name":"andre","gender":"male","probability":0.93,"count":860}', 'Niall': '{"name":"niall","gender":"male","probability":1,"count":57}', 'Jes': '{"name":"jes","gender":"female","probability":0.86,"count":44}', 'Arik': '{"name":"arik","gender":"male","probability":1,"count":11}', 'Joerg': '{"name":"joerg","gender":"male","probability":1,"count":20}', 'Witawas': '{"name":"witawas","gender":null}', 'Jef': '{"name":"jef","gender":"male","probability":1,"count":50}', 'Romain': '{"name":"romain","gender":"male","probability":0.99,"count":495}', 'Clotilde': '{"name":"clotilde","gender":"female","probability":1,"count":31}', 'Vernon': '{"name":"vernon","gender":"male","probability":1,"count":66}', 'Stan': '{"name":"stan","gender":"male","probability":0.97,"count":258}', 'Johanna': '{"name":"johanna","gender":"female","probability":1,"count":1107}', 'Christina': '{"name":"christina","gender":"female","probability":1,"count":2400}', 'Christine': '{"name":"christine","gender":"female","probability":1,"count":3115}', 'Arndt': '{"name":"arndt","gender":"male","probability":1,"count":4}', 'Olga': '{"name":"olga","gender":"female","probability":1,"count":898}', 'Coleen': '{"name":"coleen","gender":"female","probability":1,"count":56}', 'Dimitri': '{"name":"dimitri","gender":"male","probability":1,"count":197}', 'Lynette': '{"name":"lynette","gender":"female","probability":1,"count":209}', 'Ramiro': '{"name":"ramiro","gender":"male"," ...

# %%
import json
with open('data.json', 'w') as outfile:
    json.dump(hashmap, outfile)

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# Now let's cleanup and set the probabilities + perform (cp + 4 / p + 2) normalization

# %% [markdown]
# ### Group by

# %% [markdown]
# ### Further Analysis
